# %%
import pandas as pd
from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side
import os

# Tạo dữ liệu test case
test_cases = [
    {
        "Mã Test Case": "TC001",
        "Kịch bản kiểm thử": "Đăng nhập hệ thống",
        "Trường hợp kiểm thử": "Đăng nhập thành công với tài khoản hợp lệ",
        "Các bước kiểm thử": "1. Truy cập trang đăng nhập\n2. Nhập tên người dùng\n3. Nhập mật khẩu\n4. Nhấp nút Đăng nhập",
        "Dữ liệu kiểm thử": "Tên dùng: user123, Mật khẩu: pass123",
        "Kết quả dự kiến": "Người dùng được đăng nhập thành công và chuyển hướng đến trang chính",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Cao",
        "Ghi chú": "Test case cơ bản cho tính năng đăng nhập"
    },
    {
        "Mã Test Case": "TC002",
        "Kịch bản kiểm thử": "Đăng nhập hệ thống",
        "Trường hợp kiểm thử": "Đăng nhập thất bại với mật khẩu sai",
        "Các bước kiểm thử": "1. Truy cập trang đăng nhập\n2. Nhập tên người dùng\n3. Nhập mật khẩu không đúng\n4. Nhấp nút Đăng nhập",
        "Dữ liệu kiểm thử": "Tên dùng: user123, Mật khẩu: wrongpass",
        "Kết quả dự kiến": "Hiển thị thông báo lỗi 'Tên đăng nhập hoặc mật khẩu không đúng'",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Cao",
        "Ghi chú": "Kiểm tra xác thực tài khoản"
    },
    {
        "Mã Test Case": "TC003",
        "Kịch bản kiểm thử": "Đăng ký tài khoản",
        "Trường hợp kiểm thử": "Đăng ký thành công với thông tin hợp lệ",
        "Các bước kiểm thử": "1. Truy cập trang đăng ký\n2. Nhập họ tên\n3. Nhập tên người dùng\n4. Nhập email\n5. Nhập mật khẩu\n6. Xác nhận mật khẩu\n7. Chọn vai trò\n8. Đồng ý điều khoản\n9. Nhấp nút Đăng ký",
        "Dữ liệu kiểm thử": "Họ tên: Nguyễn Văn A, Tên dùng: user456, Email: user@example.com, Mật khẩu: pass@123, Vai trò: Người dùng",
        "Kết quả dự kiến": "Người dùng được đăng ký thành công và nhận thông báo 'Đăng ký thành công'",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Cao",
        "Ghi chú": "Kiểm tra quy trình đăng ký toàn bộ"
    },
    {
        "Mã Test Case": "TC004",
        "Kịch bản kiểm thử": "Đăng ký tài khoản",
        "Trường hợp kiểm thử": "Đăng ký thất bại với email đã tồn tại",
        "Các bước kiểm thử": "1. Truy cập trang đăng ký\n2. Nhập thông tin cần thiết\n3. Nhập email đã tồn tại\n4. Nhấp nút Đăng ký",
        "Dữ liệu kiểm thử": "Email: existing@example.com (đã tồn tại trong hệ thống)",
        "Kết quả dự kiến": "Hiển thị thông báo lỗi 'Email đã được đăng ký'",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Cao",
        "Ghi chú": "Kiểm tra xác thực email duy nhất"
    },
    {
        "Mã Test Case": "TC005",
        "Kịch bản kiểm thử": "Đăng ký tài khoản",
        "Trường hợp kiểm thử": "Đăng ký thất bại khi mật khẩu xác nhận không khớp",
        "Các bước kiểm thử": "1. Truy cập trang đăng ký\n2. Nhập mật khẩu: pass@123\n3. Nhập xác nhận mật khẩu: pass@456\n4. Nhấp nút Đăng ký",
        "Dữ liệu kiểm thử": "Mật khẩu: pass@123, Xác nhận: pass@456",
        "Kết quả dự kiến": "Hiển thị thông báo lỗi 'Mật khẩu xác nhận không khớp'",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Trung",
        "Ghi chú": "Kiểm tra xác thực mật khẩu"
    },
    {
        "Mã Test Case": "TC006",
        "Kịch bản kiểm thử": "Xem danh sách sự kiện",
        "Trường hợp kiểm thử": "Hiển thị danh sách sự kiện thành công",
        "Các bước kiểm thử": "1. Đăng nhập vào hệ thống\n2. Truy cập trang danh sách sự kiện\n3. Chờ dữ liệu tải",
        "Dữ liệu kiểm thử": "Tài khoản người dùng hợp lệ",
        "Kết quả dự kiến": "Danh sách sự kiện được hiển thị với đầy đủ thông tin",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Cao",
        "Ghi chú": ""
    },
    {
        "Mã Test Case": "TC007",
        "Kịch bản kiểm thử": "Tìm kiếm sự kiện",
        "Trường hợp kiểm thử": "Tìm kiếm sự kiện theo từ khóa",
        "Các bước kiểm thử": "1. Truy cập danh sách sự kiện\n2. Nhập từ khóa tìm kiếm\n3. Nhấp nút Tìm kiếm",
        "Dữ liệu kiểm thử": "Từ khóa tìm kiếm: 'Hội thảo công nghệ'",
        "Kết quả dự kiến": "Hiển thị danh sách sự kiện phù hợp với từ khóa tìm kiếm",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Trung",
        "Ghi chú": ""
    },
    {
        "Mã Test Case": "TC008",
        "Kịch bản kiểm thử": "Đăng ký tham gia sự kiện",
        "Trường hợp kiểm thử": "Đăng ký tham gia sự kiện thành công",
        "Các bước kiểm thử": "1. Xem chi tiết sự kiện\n2. Nhấp nút Đăng ký\n3. Xác nhận đăng ký",
        "Dữ liệu kiểm thử": "Sự kiện: 'Lễ hội công nghệ 2025', Người dùng: user123",
        "Kết quả dự kiến": "Người dùng được đăng ký thành công, hiển thị thông báo xác nhận",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Cao",
        "Ghi chú": ""
    },
    {
        "Mã Test Case": "TC009",
        "Kịch bản kiểm thử": "Xem lịch sử tham gia sự kiện",
        "Trường hợp kiểm thử": "Hiển thị lịch sử sự kiện đã tham gia",
        "Các bước kiểm thử": "1. Đăng nhập vào hệ thống\n2. Truy cập trang lịch sử tham gia\n3. Xem danh sách sự kiện đã tham gia",
        "Dữ liệu kiểm thử": "Tài khoản người dùng: user123",
        "Kết quả dự kiến": "Hiển thị danh sách tất cả sự kiện người dùng đã tham gia",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Trung",
        "Ghi chú": ""
    },
    {
        "Mã Test Case": "TC010",
        "Kịch bản kiểm thử": "Đăng xuất hệ thống",
        "Trường hợp kiểm thử": "Đăng xuất thành công",
        "Các bước kiểm thử": "1. Đăng nhập vào hệ thống\n2. Nhấp vào menu người dùng\n3. Nhấp nút Đăng xuất",
        "Dữ liệu kiểm thử": "Tài khoản người dùng hợp lệ",
        "Kết quả dự kiến": "Người dùng được đăng xuất thành công và chuyển hướng về trang đăng nhập",
        "Kết quả thực tế": "",
        "Vượt/Không vượt": "",
        "Độ ưu tiên": "Cao",
        "Ghi chú": ""
    }
]

# Tạo DataFrame
df = pd.DataFrame(test_cases)

# Đường dẫn lưu file
output_path = r"D:\2022-2026\HOC KI 7\XD HTTT\quanLySuKien\demo\test_cases.xlsx"

# Tạo folder nếu chưa tồn tại
os.makedirs(os.path.dirname(output_path), exist_ok=True)

# Lưu vào Excel với định dạng
with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
    df.to_excel(writer, sheet_name='Test Cases', index=False)
    
    # Lấy workbook và worksheet để định dạng
    workbook = writer.book
    worksheet = writer.sheets['Test Cases']
    
    # Thiết lập độ rộng cột
    column_widths = {
        'A': 12,  # Mã Test Case
        'B': 25,  # Kịch bản kiểm thử
        'C': 30,  # Trường hợp kiểm thử
        'D': 35,  # Các bước kiểm thử
        'E': 30,  # Dữ liệu kiểm thử
        'F': 35,  # Kết quả dự kiến
        'G': 20,  # Kết quả thực tế
        'H': 15,  # Vượt/Không vượt
        'I': 12,  # Độ ưu tiên
        'J': 25   # Ghi chú
    }
    
    for col, width in column_widths.items():
        worksheet.column_dimensions[col].width = width
    
    # Định dạng header
    header_fill = PatternFill(start_color="4472C4", end_color="4472C4", fill_type="solid")
    header_font = Font(bold=True, color="FFFFFF", size=11)
    header_alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)
    
    for cell in worksheet[1]:
        cell.fill = header_fill
        cell.font = header_font
        cell.alignment = header_alignment
    
    # Định dạng các ô dữ liệu
    thin_border = Border(
        left=Side(style='thin'),
        right=Side(style='thin'),
        top=Side(style='thin'),
        bottom=Side(style='thin')
    )
    
    for row in worksheet.iter_rows(min_row=2, max_row=worksheet.max_row, min_col=1, max_col=worksheet.max_column):
        for cell in row:
            cell.border = thin_border
            cell.alignment = Alignment(horizontal="left", vertical="top", wrap_text=True)
            # Tự động điều chỉnh chiều cao hàng
            worksheet.row_dimensions[cell.row].height = 40

print(f"✓ File test case đã được tạo thành công!")
print(f"📁 Đường dẫn: {output_path}")
print(f"📊 Tổng số test case: {len(test_cases)}")
# Out:
# ✓ File test case đã được tạo thành công tại: D:\2022-2026\HOC KI 7\XD HTTT\testcase\Test_Cases_Template.xlsx
# ✓ Tổng số test case: 5
# ✓ Định dạng: Excel (.xlsx)
